# %% [markdown]
# # Class Work
#
# Rahul is analyzing different vehicles with the help of a dataset. The dataset contains 9 following columns:
# mpg
# cylinders
# displacement
# horsepower
# weight
# acceleration
# model year
# origin
# car name
#
# Link of the dataset: auto-mpg
#
# He wants to understand the relation between mpg and the acceleration of the vehicle.
# To help Rahul use joint plot function and show the different kinds of graphs.
# kde plot
# hex plot

# %% [markdown]
# # Home Work
#
#
# Rahul wants to find how mileage depends upon the weight of the vehicle. Create a joint plot between weight and mpg and show the relation between them
#
# Also find the relation between acceleration and weight of the vehicle with the help of kde plot.

# %%
import pandas as pd
import seaborn as sns  
import numpy as np
sns.set(color_codes=True) # adds a nice background to the graphs
auto = pd.DataFrame(np.random.randn(50,5))     #creating a dummy data frame

# %%
# To plot multiple pairwise scatterplots in a dataset, you can use the pairplot() function. This creates a matrix of axes and shows the relationship for each pair of columns in a DataFrame, it also draws the histogram of each variable on the diagonal Axes:
sns.pairplot(auto[[2, 3, 1]])
