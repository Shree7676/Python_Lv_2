# %% [markdown]
# #QUE 1
#
# Shivam wants to add new data to the data frame. He wants to add one new row. Write a program to add 1 new row in the data frame.
# Given:
# [“Rich dad poor dad” , “Robert T” , 4.8 , 42000 , 7 , 2016 “Non Fiction”]

# %%
import pandas as pd
import numpy as np

file=pd.read_csv("csv_Data/books.csv")
df=pd.DataFrame(file)
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  UserRating  Reviews  Price  Year        Genre
# 0                    JJ Smith         4.7    17350      8  2016  Non Fiction
# 1                Stephen King         4.6     2052     22  2011      Fiction
# ...

# %%
len(df.index)
# Out:
# 550

# %%
df.loc[len(df.index-1)]=["Rich dad poor dad" , "Robert T" , 4.8 , 42000 ,7, 2016, "Non Fiction"]

# %%
df.loc[1.5]=["Rich dad poor dad" , "Robert T" , 4.8 , 42000 ,7, 2016, "Non Fiction"]
df=df.sort_index().reset_index(drop=True)
df
# Out:
#                                                   Name        Author  \
# 0                                    Rich dad poor dad      Robert T
# 1                                    Rich dad poor dad      Robert T
# 2                                    Rich dad poor dad      Robert T
# 3                                    11/22/63: A Novel  Stephen King
# 4                                    Rich dad poor dad      Robert T
# ..                                                 ...           ...
# 549  You Are a Badass: How to Stop Doubting Your Gr...   Jen Sincero
# 550  You Are a Badass: How to Stop Doubting Your Gr...   Jen Sincero
# 551  You Are a Badass: How to Stop Doubting Your Gr...   Jen Sincero
# 552  You Are a Badass: How to Stop Doubting Your Gr...   Jen Sincero
# 553                                  Rich dad poor dad      Robert T
#
#      UserRating  Reviews  Price  Year        Genre
# 0           4.8    42000      7  2016  Non Fiction
# ...

# %%
df.tail()
# Out:
#                                                   Name       Author  \
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 550                                  Rich dad poor dad     Robert T
#
#      UserRating  Reviews  Price  Year        Genre
# 546         4.7    14331      8  2016  Non Fiction
# 547         4.7    14331      8  2017  Non Fiction
# 548         4.7    14331      8  2018  Non Fiction
# 549         4.7    14331      8  2019  Non Fiction
# 550         4.8    42000      7  2016  Non Fiction

# %% [markdown]
# After analyzing the dataset a little bit. Shivam thinks that he should not include books in the dataset with a rating less than 4.7. To help Shivam write a program to create a new data frame containing all the books with rating more than 4.7.

# %%
df47=df.loc[df.UserRating>4.7]

# %%
(df47["UserRating"]>4.7).unique()
# Out:
# array([ True])

# %% [markdown]
# #HOME WORK

# %% [markdown]
# In the dataset, the prices of the books are mentioned in dollars. Shivam wants to add a new column price_rupees where he wants to put the prices of the books in rupees for better understanding for few users.
# Link for the price_rupees column: book_price_rupees

# %%
file2=pd.read_csv("csv_Data/book_price_rupees.csv")
dfHw=pd.DataFrame(file2)
dfHw
# Out:
#        0   600
# 0      1  1650
# 1      2  1125
# 2      3   450
# 3      4   900
# 4      5   825
# ..   ...   ...
# 544  545   600
# 545  546   600
# 546  547   600
# 547  548   600
# 548  549   600
#
# [549 rows x 2 columns]

# %%
dfHw.drop(columns="0",inplace=True)
dfHw.rename(columns={"600":"Dollar"},inplace=True)
dfHw
# Out:
#      Dollar
# 0      1650
# 1      1125
# 2       450
# 3       900
# 4       825
# ..      ...
# 544     600
# 545     600
# 546     600
# 547     600
# 548     600
#
# [549 rows x 1 columns]

# %%
dfHw["rupees"]=dfHw["Dollar"]*80
dfHw
# Out:
#      Dollar  rupees
# 0      1650  132000
# 1      1125   90000
# 2       450   36000
# 3       900   72000
# 4       825   66000
# ..      ...     ...
# 544     600   48000
# 545     600   48000
# 546     600   48000
# 547     600   48000
# 548     600   48000
#
# [549 rows x 2 columns]

# %% [markdown]
# Shivam just added price_rupees in the data frame and now he thinks that he doesn't need the price column anymore. Help Shivam in removing the price column from the dataset

# %%
dfHw.drop(columns="rupees")
# Out:
#      Dollar
# 0      1650
# 1      1125
# 2       450
# 3       900
# 4       825
# ..      ...
# 544     600
# 545     600
# 546     600
# 547     600
# 548     600
#
# [549 rows x 1 columns]
