# %%
import pandas as pd
import seaborn as sns  
import numpy as np
import matplotlib as plt
sns.set(color_codes=True) # adds a nice background to the graphs

auto = pd.DataFrame(np.random.randn(50,5))     #creating a dummy data frame

# %%
sns.displot(auto, kde=True, rug=True)

# %%
sns.lineplot(x=auto[2],y=auto[1],hue=auto[4])
# Out:
# <Axes: xlabel='2', ylabel='1'>

# %%
sns.lineplot(x=[1,2,3,4,5,6,7],y=[9,8,7,5,6,1,2])
# Out:
# <Axes: >

# %%
fil=pd.read_csv("csv_Data/books.csv")

# %%
df=pd.DataFrame(fil)

# %%
sns.lineplot(x=df.UserRating,y=df.Price,hue=df.Genre,palette="Accent",markers=["o","^"],style=df.Genre,legend=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 4
#       1 sns.lineplot(x=df.UserRating,y=df.Price,hue=df.Genre,palette="Accent",markers=["o","^"],style=df.Genre,legend=False)
# ----> 4 plt.show()
#
# File c:\Python311\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
sns.displot(df.UserRating,kde=True,rug=True,color="g",log=True)

#bins[1,2,3,4,5] 
#rug gives you below line

# %% [markdown]
# We can plot the mean of a a dataset, separated in categories using the barplot() function. When there are multiple observations in each category, it uses bootstrapping to compute a confidence interval around the estimate and plots that using error bars:
#
# sns.barplot(x=auto['body-style'], y=auto['highway-mpg'], hue=auto['fuel-type']);

# %%
sns.barplot(x=df.UserRating,y=df.Price,hue=df.Genre,ci=0)

# orient="h"
# Saturation= 0 ...
# errcolor
# errwidth
# alpha=0.5  ... entire graph will become lightBar plots
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_24424\887017807.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 0)` for the same effect.
#
#   sns.barplot(x=df.UserRating,y=df.Price,hue=df.Genre,ci=0)
# <Axes: xlabel='UserRating', ylabel='Price'>

# %% [markdown]
# A special case for the bar plot is when you want to show the number of observations in each category rather than computing the mean of a second variable. This is similar to a histogram over a categorical, rather than quantitative, variable. In seaborn, it’s easy to do so with the countplot() function:
#
#
# sns.countplot(x=auto['body-style'],hue=auto['fuel-type']);

# %%
sns.scatterplot(x=df.Reviews,y=df.Price,hue=df.Genre)
# Out:
# <Axes: xlabel='Reviews', ylabel='Price'>
